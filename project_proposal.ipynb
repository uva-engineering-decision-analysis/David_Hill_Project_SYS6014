# %% [markdown]
# # Real Estate Equipment Acquisition Analysis Tool
#
# ### Description
#
# In the real estate industry, there is a huge opportunity for digital transformation. Moreover, there is a strong need for data driven analysis tools to empower small to medium-sized real estate companies to realize their fullest potential. With this project I would like to build a decision analysis tool to help real estate development companies evaluate key business decisions to improve their business operations and customer services. Cash flow and profit/loss analysis will be central to this decision analysis tool.
#
# ### The Decision Problem
#
# * Who is the decision-maker?
#     * The owners and decision makers of small-medium sized real estate companies
#
#
# * What decision does this agent confront?
#     * Real Estate Developer:
#         * The acquisition of development equipment.
#
#
# * What is the set of options (or potential actions) from which this decision-maker chooses?
#     * Real Estate Developer
#         * Acquire or don’t Acquire development equipment (rent)
#
#
# * What are the stakes of the decision? What real costs and benefits are realized from making better vs. poorer decisions?
#     * Real Estate Developer
#         * Equipment may malfunction and may incur maintenance/repair costs
#             * Cost of Equipment VS Renting
#             * Long term benefit (Lower cost of development).
#
# ### The Predictive Tool
#
# What information does your chosen predictive tool provide?
# * It provides insights to business owners as to what strategic business decisions to make in order to grow their business.
#
# How will the decision maker use the information generated by this tool to make better decisions?
# * The tool will be used in the development of their strategic business development or expansion plan which they can execute on.
#
# The main goal in this analysis is to derive a model that maximizes the value of acquiring a piece of development equipment while minimizing the risk as a function of cost. Essentially, we want the biggest bang for our buck. We will use a bulldozer as an example of a piece of development equipment.
#
# #### Formal Description
#
# ---
# The decision-maker's action set $\ A:$
#
# $\alpha_{1}, \alpha_{2} ,..., \alpha_{n} \in \ A$
#
# $\ A = \{\alpha_{1} = 1, \alpha_{2} = 0\}$
#
# where:
#
# $\alpha_{1}$ = Buy a new bulldozer for new construction
# $\alpha_{2}$ = Lease a bulldozer for new construction
#
#
# ---
# The state space: $\ X$
#
# $\chi_{1}, \chi_{2} ,..., \chi_{n} \in \ X$
#
# $\ X = \{\chi_{1}, \chi_{2},  \chi_{3}\}$
#
# where:
#
# $\chi_{1}$ = Bulldozer is operational
# $\chi_{2}$ = Bulldozer is NOT operational
# $\chi_{3}$ = Do not buy s bulldozer
#
# > Note: More states will be added as needed
#
#
# ---
# The parameter space $\Theta$
#
# $\theta_{1}, \theta_{2} ,..., \theta_{n} \in \Theta$
#
# $\Theta = \{\theta_{1}, \theta_{2}\}$
#
# where:
#
# $\theta_{1}$ = Probability that the equiptment will fail
# $\theta_{2}$ = Probability that the equiptment NOT will fail
#
#
# ---
# #### Data Generating Process
#
# [Data Source]
#
# As a part of the data generation process, we will look at data provided by Komatsu, a reputable bulldozer supplier. We will also be scraping bulldozer data as needed from websites we find.
#
# ---
# #### Prior Beliefs
#
# One assumption the client has is that buying a new bulldozer will result in higher productivity due to a lessened need to transport the bulldozer frequently. It is also assumed that the probability that a new bulldozer will malfunction is lower than that of a used rented one. It is finally assumed that a rented bulldozer has lower maintenance costs. However, the new bulldozer is expected to have a higher payoff as it helps vertically integrate the client’s business. The bulldozer can be classified as an asset to the business which can enable tax benefits and enhanced operational capabilities.
#
# ---
# #### Getting Better Information
#
# We will sharpen the decision maker’s beliefs by performing Bayesian analysis on collected bulldozer data that we will collect and/or simulate. This data will show us the estimated work hours we can get from different classes of bulldozers, as well as repair cost data. More data and research in this topic may reveal other unobserved parameters that need to be accounted for.
#
# ---
# #### Payoffs
# * Buying
#     * Higher productivity and utility from the equipment.
#     * Lower long-term cost of owning the equipment
#     * Growth enabler of the business and improved operational capabilities
#
#
# * Renting
#     * Less risk in the case of a malfunction.
#     * Can use as needed and will remove liability from the real estate business owner.
#
# ---
# #### Utility/Loss Function
#
# The utility function for this project will be a function of the user’s action and the parameter relating to its chance to need a costly maintenance. It is important for the utility function to incorporate cost as the cost of a repair and the cost of ownership/leasing should not exceed the value or payoff we get from a particular decision
#
# ---
# #### Rules
#
# Only one decision can be made. Once chosen, the outcome of said choice is immutable
